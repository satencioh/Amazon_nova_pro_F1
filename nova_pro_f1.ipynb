# %% [markdown]
# ### Amazon Nova Pro 🚩🏁
# Es un modelo multimodal de gran capacidad con la mejor combinación de precisión, velocidad y costo para una amplia gama de tareas.
#
# A continuacion tomamos el caso de uso de un video resumen de una carrera cualquiera de Formula 1 con el fin de conocer mas sobre este deporte mediante la explicacion y analisis que nos proporcionara Amazon Nova Pro.
#
# Este ejercicio fue pensando para aquellos novatos en Formula 1 como yo 🍑♥️

# %%
import boto3
import json

# Create a Bedrock Runtime client in the AWS Region of your choice.
client = boto3.client(
    "bedrock-runtime",
    region_name="us-east-1",
)

MODEL_ID = "us.amazon.nova-pro-v1:0"


# Define user input
input_prompt = (
"""
¡Hola! Soy nuevo en la Fórmula 1 y estoy viendo este video resumen de una carrera. La verdad, ¡no entiendo casi nada de lo que pasa!

¿Podrías ser mi guía personal y enforcar tu explicacion netamente en este video? Imagina que es la primera vez que veo una carrera de F1. Presta mucha atención a lo que sucede en el video y explícame los siguientes puntos con un lenguaje muy sencillo y claro, sin asumir que sé algo:

¿Qué autos se ven con frecuencia y qué acciones clave están realizando en las tomas que aparecen?
¿Qué información clave están transmitiendo los gráficos, tablas o textos que aparecen en la pantalla de este video (por ejemplo, posiciones de los pilotos, diferencias de tiempo)?
¿Hay algún evento importante ocurriendo ahora mismo en el video (por ejemplo, adelantamientos, paradas en boxes, incidentes o el despliegue de banderas de color)? Explica qué significa cada uno y por qué es relevante dentro del contexto de esta carrera específica si el video da pistas.
¿Qué partes del circuito se muestran en el video (curvas icónicas, la recta principal, la entrada o salida de boxes) y qué está ocurriendo allí en este resumen?
Quiero que tu explicación se centre en ayudarme a interpretar lo que estoy viendo en este video en particular.
"""
)


#S3 Location: Use for larger files, (Recommended for payload greater than 25MB upto 1GB)
s3_video_path = "s3://gpformula1/GrandPrix_f1.mp4"

# Video format, supported formats atm: MP4, MOV, MKV, WebM, FLV, MPEG, MPG, WMV, 3GP
vid_format = "mp4"

# Define a "user" message including both the image and a text prompt.
message_list = [
    {
        "role": "user",
        "content": [
            {
                "video": {
                    "format": vid_format,
                    "source": {
                        "s3Location": {
                            "uri": s3_video_path
                        }
                    }
                }
            },
            {
                "text": input_prompt
            }
        ]
    }
]

# Inference parameters
inf_params = {"maxTokens": 1000, "topP": 0.8, "temperature": 0.3}

try:
    response = client.converse(
        modelId=MODEL_ID,
        messages=message_list,
        inferenceConfig=inf_params
    )

    response_text = response["output"]["message"]["content"][0]["text"]
    print(response_text)

except Exception as e:
    print("Error al invocar el modelo:", str(e))
# Out:
# ¡Claro! Aquí tienes una explicación sencilla de lo que sucede en el video:
#
# **Autos y acciones clave:**
#
# *   En el video, se ven principalmente autos de Fórmula 1 de diferentes equipos y colores. Los autos están compitiendo en una pista de carreras, y las acciones clave incluyen:
#     *   Adelantamientos: Los autos se mueven rápidamente y tratan de superar a otros autos para mejorar su posición en la carrera.
#     *   Paradas en boxes: Los autos entran en un área especial de la pista llamada "boxes" para cambiar neumáticos, ajustar el auto o repostar combustible.
#     *   Incidentes: En algunas partes del video, se ven autos que han sufrido algún tipo de problema o accidente, como choques o salidas de pista.
#
# **Información clave en gráficos y textos:**
#
# *   Los gráficos y textos en la pantalla proporcionan información importante sobre la carrera, como:
#     *   Posiciones de los pilotos: Se muestra la clasificación de los pilotos en tiempo real, con el número del auto y el nombre del piloto.
#     *   Diferencias de tiempo: Se indica la diferencia de tiempo entre los pilotos líderes y los que les siguen, lo que ayuda a entender la intensidad de la competencia.
#     *   Banderas: Se muestran banderas de diferentes colores que indican situaciones específicas en la carrera, como la bandera amarilla que indica peligro en la pista o la bandera a cuadros que señala el final de la carrera.
#
# **Eventos importantes:**
#
# *   En el video, se pueden ver varios eventos importantes, como:
#     *   Adelantamientos: Los pilotos intentan superar a sus rivales en la pista para ganar posiciones.
#     *   Paradas en boxes: Los autos entran en boxes para realizar cambios de neumáticos o ajustes en el auto.
#     *   Incidentes: En algunas partes del video, se ven autos que han sufrido algún tipo de problema o accidente, como choques o salidas de pista.
#
# **Partes del circuito:**
#
# *   El video muestra diferentes partes del circuito de carreras, como:
#     *   Curvas icónicas: Se ven curvas famosas del circuito donde los pilotos deben ser hábiles para mantener el control del auto.
#     *   Recta principal: La recta principal es una sección larga y recta de la pista donde los autos alcanzan su máxima velocidad.
#     *   Entrada y salida de boxes: Se muestra la entrada y salida de boxes, donde los autos pueden detenerse para realizar reparaciones o cambios de neumáticos.
#
# En resumen, el video muestra una emocionante carrera de Fórmula 1 con autos compitiendo en una pista de carreras, realizando adelantamientos, paradas en boxes y enfrentando incidentes. Los gráficos y textos en la pantalla proporcionan información clave sobre la carrera, como las posiciones de los pilotos y las diferencias de tiempo. ¡Espero que esto te ayude a entender mejor lo que estás viendo en el video!
